# %%
#Instructions: run each cell one after the other to load data, generate dictionaries, and plot graphs
#Note: replace file paths with your file paths if different

# %%
import pandas as pd 
from matplotlib import pyplot as plt
import numpy as np
from collections import defaultdict

# %%
#replace with your path of resultsHybridSPRO_Gamma.xlsx file if different
ch_DA_gamma0 = pd.read_excel (r'resultsHybridSPRO_Gamma.xlsx', sheet_name='chBDA')
ch_DA_gamma0 = ch_DA_gamma0['chDA']
ch_DA_gamma0 = ch_DA_gamma0[0:]
dis_DA_gamma0 = pd.read_excel (r'resultsHybridSPRO_Gamma.xlsx', sheet_name='disBDA')
dis_DA_gamma0 = dis_DA_gamma0['disDA']
dis_DA_gamma0 = dis_DA_gamma0[0:]

# %%
chDA1 = []
chDA12 = []
chDA24 = []


disDA1 = []
disDA12 = []
disDA24 = []

# %%
for i in range (0, len(ch_DA_gamma0), 25):
    chDA1.append(ch_DA_gamma0[i])
    chDA12.append(ch_DA_gamma0[i+12])
    chDA24.append(ch_DA_gamma0[i+24])

    disDA1.append(-dis_DA_gamma0[i])
    disDA12.append(-dis_DA_gamma0[i+12])
    disDA24.append(-dis_DA_gamma0[i+24])

# %%
# Replace with your path if different
df =  pd.read_excel (r'resultsHybridSPRO_Gamma.xlsx', sheet_name='chBIBplus')

# Initialize nested dictionary
scenario_alpha_data_ch_plus = defaultdict(lambda: defaultdict(list))

#dictionary generation
for i in range(len(df)):
    scenario = df.loc[i, 'scenario']
    alpha = df.loc[i, 'alpha']
    ch_plus = df.loc[i, 'ch_plus']
    scenario_alpha_data_ch_plus[scenario][alpha].append(ch_plus)
        

#convert to regular dict (for cleaner printing or export)
scenario_alpha_data_ch_plus = {k: dict(v) for k, v in scenario_alpha_data_ch_plus.items()}

#print the ch_plus list for scenario 1 and alpha 1 
print(scenario_alpha_data_ch_plus[1.0][1.0])
# Out:
# [0.0, 4.4728260869565215, 0.0, 4.4728260869565215, 0.0, 4.4728260869565215, 0.0, 4.4728260869565215, 0.0, 4.4728260869565215, 0.0, 0.0, 0.0, 0.0, 4.4728260869565215, 0.0, 3.5760869565217397, 0.0, 4.4728260869565215, 0.0, 0.0, 4.4728260869565215, 0.0, 0.0]

# %%
# Replace with your path if different
df =  pd.read_excel (r'resultsHybridSPRO_Gamma.xlsx', sheet_name='chBIBminus')

scenario_alpha_data_ch_minus = defaultdict(lambda: defaultdict(list))

for i in range(len(df)):
    scenario = df.loc[i, 'scenario']
    alpha = df.loc[i, 'alpha']
    ch_minus = df.loc[i, 'ch_minus']
    scenario_alpha_data_ch_minus[scenario][alpha].append(ch_minus)


#convert to regular dict (for cleaner printing or export)
scenario_alpha_data_ch_minus = {k: dict(v) for k, v in  scenario_alpha_data_ch_minus.items()}

#print the ch_minus list for scenario 1 and alpha 1
print(scenario_alpha_data_ch_minus[1.0][1.0])
# Out:
# [4.4728260869565215, 0.0, 4.4728260869565215, 0.0, 4.4728260869565215, 0.0, 4.4728260869565215, 0.0, 4.4728260869565215, 0.0, 4.4728260869565215, 0.0, 4.4728260869565215, 0.8252228488266334, 0.0, 4.4728260869565215, 0.0, 4.4728260869565215, 0.0, 4.4728260869565215, 0.8252228488266334, 0.0, 4.4728260869565215, 0.8252228488266334]

# %%
# Replace with your path if different
df =  pd.read_excel (r'resultsHybridSPRO_Gamma.xlsx', sheet_name='disBIBplus')

scenario_alpha_data_dis_plus = defaultdict(lambda: defaultdict(list))

for i in range(len(df)):
    scenario = df.loc[i, 'scenario']
    alpha = df.loc[i, 'alpha']
    dis_plus = df.loc[i, 'dis_plus']
    scenario_alpha_data_dis_plus[scenario][alpha].append(-dis_plus)


#convert to regular dict (for cleaner printing or export)
scenario_alpha_data_dis_plus = {k: dict(v) for k, v in  scenario_alpha_data_dis_plus.items()}

#print the dis_plus list for scenario 1 and alpha 1
print(scenario_alpha_data_dis_plus[1.0][1.0])
# Out:
# [-0.0, -0.0, -3.7858000000000005, -0.0, -3.7858000000000005, -0.0, -3.7858000000000005, -0.0, -3.7858000000000005, -0.0, -3.7858000000000005, -0.0, -0.0, -0.0, -0.0, -2.7278000000000002, -0.0, -4.0848, -0.0, -3.7858000000000005, -0.0, -0.0, -3.7858000000000005, -0.0]

# %%
# Replace with your path if different
df =  pd.read_excel (r'resultsHybridSPRO_Gamma.xlsx', sheet_name='disBIBminus')


scenario_alpha_data_dis_minus = defaultdict(lambda: defaultdict(list))

for i in range(len(df)):
    scenario = df.loc[i, 'scenario']
    alpha = df.loc[i, 'alpha']
    dis_minus = df.loc[i, 'dis_minus']
    if (dis_minus>0.15):
         scenario_alpha_data_dis_minus[scenario][alpha].append(-dis_minus)
    else: 
        scenario_alpha_data_dis_minus[scenario][alpha].append(0)

#convert to regular dict (for cleaner printing or export)
scenario_alpha_data_dis_minus = {k: dict(v) for k, v in  scenario_alpha_data_dis_minus.items()}

#print the dis_minus list for scenario 1 and alpha 1
print(scenario_alpha_data_dis_minus[1.0][1.0])
# Out:
# [0, -3.7858000000000005, 0, -3.7858000000000005, 0, -3.7858000000000005, 0, -3.7858000000000005, 0, -3.7858000000000005, 0, -3.7858000000000005, 0, 0, -4.484268619246863, 0, -3.7858000000000005, 0, -3.7858000000000005, 0, 0, -4.484268619246863, 0, 0]

# %%
X = np.arange(0,25)
Y = np.arange(-5,6)
width = 0.9
fig, axs = plt.subplots(3, 1,figsize=(25,15), constrained_layout = True)

hw=0.2
hl=0.3
arrow_width = 0.05




for i in range (0,24):

            
        
            if(disDA1[i] ==0 and chDA1[i]!= 0):
                axs[0].bar(X[i], chDA1[i], width , color='silver', label='Charging/discharging in the DA market')        
                axs[0].arrow(X[i] - 0.33, chDA1[i], 0,  scenario_alpha_data_ch_plus[1][1][i],
                      color='deeppink',label='S1', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[0].arrow(X[i] - 0.33, chDA1[i], 0,  -scenario_alpha_data_ch_minus[1][1][i] + scenario_alpha_data_dis_plus[1][1][i],
                      color='deeppink', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
        
         
                axs[0].arrow(X[i] , chDA1[i], 0,  scenario_alpha_data_ch_plus[5][1][i],
                      color='darkorange',label='S5', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[0].arrow(X[i], chDA1[i], 0,  -scenario_alpha_data_ch_minus[5][1][i]+ scenario_alpha_data_dis_plus[5][1][i],
                      color='darkorange', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)

                axs[0].arrow(X[i] + 0.33, chDA1[i], 0,  scenario_alpha_data_ch_plus[10][1][i],
                      color='rebeccapurple',label='S10', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[0].arrow(X[i] + 0.33, chDA1[i], 0,  -scenario_alpha_data_ch_minus[10][1][i]+ scenario_alpha_data_dis_plus[10][1][i],
                      color='rebeccapurple', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                
            elif(disDA1[i] !=0 and chDA1[i] == 0):
                axs[0].bar(X[i], disDA1[i], width , color='silver', label='Discharging in the DA market')    
                    
           
                axs[0].arrow(X[i] - 0.33, disDA1[i], 0,  scenario_alpha_data_dis_plus[1][1][i],
                      color='deeppink',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[0].arrow(X[i] - 0.33, disDA1[i], 0,  -scenario_alpha_data_dis_minus[1][1][i] + scenario_alpha_data_ch_plus[1][1][i],
                      color='deeppink',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
           
            
          
                axs[0].arrow(X[i] , disDA1[i], 0,  scenario_alpha_data_dis_plus[5][1][i],
                      color='darkorange',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[0].arrow(X[i] , disDA1[i], 0,  -scenario_alpha_data_dis_minus[5][1][i]+ scenario_alpha_data_ch_plus[5][1][i],
                      color='darkorange',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
            
            
                axs[0].arrow(X[i] + 0.33, disDA1[i], 0,  scenario_alpha_data_dis_plus[10][1][i],
                      color='rebeccapurple',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
            
                axs[0].arrow(X[i] + 0.33, disDA1[i], 0,  -scenario_alpha_data_dis_minus[10][1][i] + scenario_alpha_data_ch_plus[10][1][i],
                      color='rebeccapurple',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
            
            elif(disDA1[i] == 0 and chDA1[i] == 0):
                axs[0].bar(X[i], chDA1[i], width , color='silver', label='Dis_DA')        
                axs[0].arrow(X[i] - 0.33, chDA1[i], 0,  scenario_alpha_data_ch_plus[1][1][i],
                      color='deeppink',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[0].arrow(X[i] - 0.33, chDA1[i], 0,  scenario_alpha_data_dis_plus[1][1][i] ,
                      color='deeppink',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
               
                axs[0].arrow(X[i] , chDA1[i], 0,  scenario_alpha_data_ch_plus[5][1][i],
                      color='darkorange',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[0].arrow(X[i] , chDA1[i], 0,  scenario_alpha_data_dis_plus[5][1][i],
                      color='darkorange',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                
                axs[0].arrow(X[i] + 0.33, chDA1[i], 0,  scenario_alpha_data_ch_plus[10][1][i],
                      color='rebeccapurple',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[0].arrow(X[i] + 0.33, chDA1[i], 0,  scenario_alpha_data_dis_plus[10][1][i] ,
                      color='rebeccapurple',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
            
            
            axs[0].set_title('Γ$^{IB}$=0',fontsize=35)
            axs[0].grid()
            axs[0].tick_params(axis='both', which='major', labelsize=30)
            if (i==0):
                axs[0].legend(loc='upper center', bbox_to_anchor=(0,0.65,1,1),ncol=4,mode='expand', fontsize=35)


            
            
                
        
            

           
            
         
            if(disDA12[i] ==0 and chDA12[i]!= 0):
                axs[1].bar(X[i], chDA12[i], width , color='silver', label='Dis_DA')        
                axs[1].arrow(X[i] - 0.33, chDA12[i], 0,  scenario_alpha_data_ch_plus[1][13][i],
                      color='deeppink',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[1].arrow(X[i] - 0.33, chDA12[i], 0,  -scenario_alpha_data_ch_minus[1][13][i] + scenario_alpha_data_dis_plus[1][13][i],
                      color='deeppink',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                
                axs[1].arrow(X[i] , chDA12[i], 0,  scenario_alpha_data_ch_plus[5][13][i],
                      color='darkorange',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[1].arrow(X[i] , chDA12[i], 0,  -scenario_alpha_data_ch_minus[5][13][i] + scenario_alpha_data_dis_plus[5][13][i],
                      color='darkorange',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                
                axs[1].arrow(X[i] + 0.33, chDA12[i], 0,  scenario_alpha_data_ch_plus[10][13][i],
                      color='rebeccapurple',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[1].arrow(X[i] + 0.33, chDA12[i], 0,  -scenario_alpha_data_ch_minus[10][13][i] + scenario_alpha_data_dis_plus[10][13][i],
                      color='rebeccapurple',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                

            elif(disDA12[i] !=0 and chDA12[i] == 0):
                axs[1].bar(X[i], disDA12[i], width , color='silver', label='Dis_DA')        
                axs[1].arrow(X[i] - 0.33, disDA12[i], 0, scenario_alpha_data_dis_plus[1][13][i],
                      color='deeppink',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[1].arrow(X[i] - 0.33, disDA12[i], 0,  -scenario_alpha_data_dis_minus[1][13][i] + scenario_alpha_data_ch_plus[1][13][i],
                      color='deeppink',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                     
           
                axs[1].arrow(X[i] , disDA12[i], 0,  scenario_alpha_data_dis_plus[5][13][i],
                      color='darkorange',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[1].arrow(X[i] , disDA12[i], 0,  -scenario_alpha_data_dis_minus[5][13][i] + scenario_alpha_data_ch_plus[5][13][i],
                      color='darkorange',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
            
                axs[1].arrow(X[i] + 0.33, disDA12[i], 0, scenario_alpha_data_dis_plus[10][13][i],
                      color='rebeccapurple',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[1].arrow(X[i] + 0.33, disDA12[i], 0,  -scenario_alpha_data_dis_minus[10][13][i]+ scenario_alpha_data_ch_plus[10][13][i],
                      color='rebeccapurple',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                
            elif(disDA12[i] == 0 and chDA12[i] == 0):
                axs[1].bar(X[i], chDA12[i], width , color='silver', label='Dis_DA')        
                axs[1].arrow(X[i] - 0.33, chDA12[i], 0,  scenario_alpha_data_ch_plus[1][13][i],
                      color='deeppink',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[1].arrow(X[i] - 0.33, chDA12[i], 0,  scenario_alpha_data_dis_plus[1][13][i] ,
                      color='deeppink',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
               
                axs[1].arrow(X[i] , chDA12[i], 0,  scenario_alpha_data_ch_plus[5][13][i],
                      color='darkorange',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[1].arrow(X[i] , chDA12[i], 0,  scenario_alpha_data_dis_plus[5][13][i],
                      color='darkorange',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                
                axs[1].arrow(X[i] + 0.33, chDA12[i], 0,  scenario_alpha_data_ch_plus[10][13][i],
                      color='rebeccapurple',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[1].arrow(X[i] + 0.33, chDA12[i], 0,  scenario_alpha_data_dis_plus[10][13][i] ,
                      color='rebeccapurple',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                
            axs[1].set_title('Γ$^{IB}$=12',fontsize=35)
            axs[1].tick_params(axis='both', which='major', labelsize=30)
            
            
            
            
            
            
         
            
            if(disDA24[i] ==0 and chDA24[i]!= 0):
                axs[2].bar(X[i], chDA24[i], width , color='silver', label='Discharging on the DA market')        
                axs[2].arrow(X[i] - 0.33, chDA24[i], 0,  scenario_alpha_data_ch_plus[1][25][i],
                      color='deeppink',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[2].arrow(X[i] - 0.33, chDA24[i], 0,  -scenario_alpha_data_ch_minus[1][25][i] + scenario_alpha_data_dis_plus[1][25][i],
                      color='deeppink',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                
                axs[2].arrow(X[i] , chDA24[i], 0,  scenario_alpha_data_ch_plus[5][25][i],
                      color='darkorange',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[2].arrow(X[i] , chDA24[i], 0,  -scenario_alpha_data_ch_minus[5][25][i] + scenario_alpha_data_dis_plus[5][25][i],
                      color='darkorange',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                
                axs[2].arrow(X[i] + 0.33, chDA24[i], 0,  scenario_alpha_data_ch_plus[10][25][i],
                      color='rebeccapurple',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[2].arrow(X[i] + 0.33, chDA24[i], 0,  -scenario_alpha_data_ch_minus[10][25][i] + scenario_alpha_data_dis_plus[10][25][i],
                      color='rebeccapurple',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                     
                
            elif(disDA24[i] !=0 and chDA24[i] == 0):
                axs[2].bar(X[i], disDA24[i], width , color='silver', label='Discharging on the DA market')        
                axs[2].arrow(X[i] - 0.33, disDA24[i], 0,  scenario_alpha_data_dis_plus[1][25][i],
                      color='deeppink',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[2].arrow(X[i] - 0.33, disDA24[i], 0,  -scenario_alpha_data_dis_minus[1][25][i] + scenario_alpha_data_ch_plus[1][25][i],
                      color='deeppink',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)               
                axs[2].arrow(X[i] , disDA24[i], 0,  scenario_alpha_data_dis_plus[5][25][i],
                      color='darkorange',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[2].arrow(X[i] , disDA24[i], 0,  -scenario_alpha_data_dis_minus[5][25][i]  + scenario_alpha_data_ch_plus[5][25][i],
                      color='darkorange',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                
                axs[2].arrow(X[i] + 0.33, disDA24[i], 0,  scenario_alpha_data_dis_plus[10][25][i],
                      color='rebeccapurple',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[2].arrow(X[i] + 0.33, disDA24[i], 0,  -scenario_alpha_data_dis_minus[10][25][i] + scenario_alpha_data_ch_plus[10][25][i],
                      color='rebeccapurple',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                             
            elif(disDA24[i] == 0 and chDA24[i] == 0):
                axs[2].bar(X[i], chDA24[i], width , color='silver', label='Dis_DA')        
                axs[2].arrow(X[i] - 0.33, chDA24[i], 0,  scenario_alpha_data_ch_plus[1][25][i],
                      color='deeppink',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[2].arrow(X[i] - 0.33, chDA24[i], 0,  scenario_alpha_data_dis_plus[1][25][i] ,
                      color='deeppink',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[2].arrow(X[i] , chDA24[i], 0,  scenario_alpha_data_ch_plus[5][25][i],
                      color='darkorange',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[2].arrow(X[i] , chDA24[i], 0,  scenario_alpha_data_dis_plus[5][25][i],
                      color='darkorange',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)           
                axs[2].arrow(X[i] + 0.33, chDA24[i], 0,  scenario_alpha_data_ch_plus[10][25][i],
                      color='rebeccapurple',label='Dis_plus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                axs[2].arrow(X[i] + 0.33, chDA24[i], 0,  scenario_alpha_data_dis_plus[10][25][i] ,
                      color='rebeccapurple',  label='Dis_minus', length_includes_head=True,head_width=hw, 
                      head_length=hl, width=arrow_width)
                
                
            axs[2].set_title('Γ$^{IB}$=24',fontsize=35)
            axs[2].tick_params(axis='both', which='major', labelsize=30)       
            

axs[0].axis(ymin=-5,ymax=5)
axs[1].axis(ymin=-5,ymax=5)
axs[2].axis(ymin=-5,ymax=5)


                       



for ax in axs.flat:
    ax.set_ylabel('Power [MW]',fontsize=35)
    ax.tick_params(axis='both', which='major', labelsize=35)
    ax.set_xticks(np.arange(len(X)))
    ax.set_xticklabels(X)
    ax.grid(True, axis='y')
   
#Replace with your path if different

fig.savefig('fig_12.pdf',
            format='pdf',
            dpi=100,
            bbox_inches='tight')
